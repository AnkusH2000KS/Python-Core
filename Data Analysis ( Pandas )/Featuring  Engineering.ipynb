# %%
# Class (18-05-2022) From Madrid Institute

# %% [raw]
# Feature Engenerring
#  Adding Columns
#  Edit Columns
# Encoding Technique
#  Label Encoding - ordinal
#  One hot Encoding - Nominal
#    LABEL - Map, Replace,label Enc
#    ONE HOT - Get Dummies, One Hot Encoder
# Lambda - Anonynes
#   Keyword helps in making Anomynes Function

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df["species"] = df["species"].map ({"setosa":0,"versicolor":1,"verginica":2})

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      0.0
# 1             4.9          3.0           1.4          0.2      0.0
# 2             4.7          3.2           1.3          0.2      0.0
# 3             4.6          3.1           1.5          0.2      0.0
# 4             5.0          3.6           1.4          0.2      0.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      NaN
# 146           6.3          2.5           5.0          1.9      NaN
# 147           6.5          3.0           5.2          2.0      NaN
# 148           6.2          3.4           5.4          2.3      NaN
# 149           5.9          3.0           5.1          1.8      NaN
#
# [150 rows x 5 columns]

# %%
#df["species"].astype("int")

# %%
#df["species"] = df["species"].replace({0:"zero",1:"one",2:"two"})

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      0.0
# 1             4.9          3.0           1.4          0.2      0.0
# 2             4.7          3.2           1.3          0.2      0.0
# 3             4.6          3.1           1.5          0.2      0.0
# 4             5.0          3.6           1.4          0.2      0.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      NaN
# 146           6.3          2.5           5.0          1.9      NaN
# 147           6.5          3.0           5.2          2.0      NaN
# 148           6.2          3.4           5.4          2.3      NaN
# 149           5.9          3.0           5.1          1.8      NaN
#
# [150 rows x 5 columns]

# %%
pd.get_dummies(df["species"],drop_first = True)
# Out:
#      1.0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
#
# [150 rows x 1 columns]

# %%
df["sq_sepal_length"] = df["sepal_length"].apply(lambda x:x**2)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0             5.1          3.5           1.4          0.2      0.0
# 1             4.9          3.0           1.4          0.2      0.0
# 2             4.7          3.2           1.3          0.2      0.0
# 3             4.6          3.1           1.5          0.2      0.0
# 4             5.0          3.6           1.4          0.2      0.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      NaN
# 146           6.3          2.5           5.0          1.9      NaN
# 147           6.5          3.0           5.2          2.0      NaN
# 148           6.2          3.4           5.4          2.3      NaN
# 149           5.9          3.0           5.1          1.8      NaN
#
#      sq_sepal_length
# 0              26.01
# 1              24.01
# 2              22.09
# 3              21.16
# 4              25.00
# ..               ...
# ...

# %%
df["sq_sepal_length"] = df["sq_sepal_length"].astype("int")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0             5.1          3.5           1.4          0.2      0.0
# 1             4.9          3.0           1.4          0.2      0.0
# 2             4.7          3.2           1.3          0.2      0.0
# 3             4.6          3.1           1.5          0.2      0.0
# 4             5.0          3.6           1.4          0.2      0.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      NaN
# 146           6.3          2.5           5.0          1.9      NaN
# 147           6.5          3.0           5.2          2.0      NaN
# 148           6.2          3.4           5.4          2.3      NaN
# 149           5.9          3.0           5.1          1.8      NaN
#
#      sq_sepal_length
# 0                 26
# 1                 24
# 2                 22
# 3                 21
# 4                 25
# ..               ...
# ...

# %%
df["sq_sepal_length"].apply(lambda x:x%2==0)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147     True
# 148     True
# 149     True
# Name: sq_sepal_length, Length: 150, dtype: bool

# %%
df["new"] = df["sq_sepal_length"].apply(lambda x:x%2==0)

# %%
df.drop(columns = ["new"],inplace = True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0             5.1          3.5           1.4          0.2      0.0
# 1             4.9          3.0           1.4          0.2      0.0
# 2             4.7          3.2           1.3          0.2      0.0
# 3             4.6          3.1           1.5          0.2      0.0
# 4             5.0          3.6           1.4          0.2      0.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      NaN
# 146           6.3          2.5           5.0          1.9      NaN
# 147           6.5          3.0           5.2          2.0      NaN
# 148           6.2          3.4           5.4          2.3      NaN
# 149           5.9          3.0           5.1          1.8      NaN
#
#      sq_sepal_length   naya
# 0                 26   True
# 1                 24   True
# 2                 22   True
# 3                 21  False
# ...
