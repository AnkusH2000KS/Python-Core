# %% [raw]
# Class (24-05-2022) From Madrid Software Institute.

# %% [raw]
# =====================================================

# %% [raw]
# DATA VISUALIZATION
# - visnalize
# - data visulization liabarary
# - matplot
# -seaborn
# -plotly
# -pandas
# -cutflinks
# -boken
# -numpy
# -matlab
# -ggplot.
#
# MATLAB = Electronic , matplotolib ,pylab
#         pyplot as plt
#         import
#
#         functions = lineplot - line graph
#                     scatterplot - dotted graph
#                     pyplot - pie graph(Share ex)\
#
# xlabel = labelling
# xticks = scale

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  #import warming
  #warmings.filterwarnings("ignore") IF WARNING OCCUR

# %%
#matplotlib inline = output will static image of the plot embarded in notebook

# %%
plt.figure(figsize= (5,5))
plt.axis() #(START , END)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# %matplotlib inline
x1 = np.linspace(0,10,100)
#creating a figure
fig = plt.figure()

plt.plot(x1, np.sin(x1),"--k");
plt.plot(x1,np.cos(x1),"or");

# %%
#default 
plt.plot(x1, np.sin(x1),);
plt.plot(x1,np.cos(x1),);

# %%
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
x = df[df["year"]==1949][["month","passengers"]]
x
# Out:
#    month  passengers
# 0    Jan         112
# 1    Feb         118
# 2    Mar         132
# 3    Apr         129
# 4    May         121
# 5    Jun         135
# 6    Jul         148
# 7    Aug         148
# 8    Sep         136
# 9    Oct         119
# 10   Nov         104
# 11   Dec         118

# %%
plt.plot(x["month"].unique(),x["passengers"],"k");

# %%
plt.plot(x["month"].unique(),x["passengers"],"k");
plt.xticks(rotation = 90);

# %%
x["passengers"].sum()
# Out:
# 1520

# %% [raw]
# SUBPLOT

# %%
plt.figure(figsize = (10,5))

plt.subplot(1,2,2)
plt.plot(x1, np.sin(x1));

plt.subplot(1,2,1)
plt.plot(x1, np.cos(x1));

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["embarked"].fillna(df["embarked"].mode()[0],inplace = True)

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.bar(df["survived"],df["fare"]);

plt.subplot(2,2,2)
plt.bar(df["sex"],df["fare"]);

plt.subplot(2,2,3)
plt.bar(df["embarked"],df["fare"]);

plt.subplot(2,2,4)
plt.bar(df["pclass"],df["fare"]);

# %%
plt.bar(df["embarked"],df["fare"]);

# %% [raw]
# ==================================================================

# %% [raw]
# Class(25-05-2022) From Madrid Software Institute.

# %% [raw]
# ==================================================================

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.figure(figsize = (10,10))
plot_number = 1
for i in["survived","pclass","sex","embarked"]:
    if plot_number<5:
        plt.subplot(2,2,plot_number)
        plt.bar(df[i],df["fare"])
        plt.xlabel(i)
    plot_number+=1

# %%
plt.plot([1,8,10,5,6],[1,2,3,4,5])
plt.ylabel('Numbers')
plt.xlabel('x variable')
plt.title('list plot on matplotlib')
plt.xticks(np.arange(1,11,1))
plt.yticks(np.arange(1,10,2))
plt.show();

# %%
x = np.linspace(0,2,100)
plt.plot(x,x,label = 'linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label = 'cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Simple Plot')
plt.legend()
plt.show()

# %%
y = np.linspace(0,5,50)
plt.plot(y,y,"r--",y,y**2,"bs",y,y**3,"g^")
plt.show();

# %%
x3 = np.arange(0.6,6.0,0.01)
plt.plot(x3,[i**2 for i in x3])
plt.show();

# %%
figure = plt.figure(figsize = (5,5))
plt.plot([1,2,3,4],[1,8,27,64],"r--")
plt.title("Example To save a File")
plt.show();
figure.savefig("cube.png")

# %%
from IPython.display import Image
Image("cube.png")

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig = plt.figure()
ax =plt.axes()
x5 = np.linspace(0,10,100)
ax.plot(x5,np.sin(x5),"b-");
