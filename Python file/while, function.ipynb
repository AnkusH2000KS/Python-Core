# %%
a = 5
for i in range(1,11):
    print(i*a)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
n = 11

# %%
n%2==0
# Out:
# False

# %%
n%3==0
# Out:
# False

# %%
n = 15
for i in range(2,n):
    print(n%i==0)
# Out:
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
is_prime = True
n = 2
for i in range(2,n):
    if n%i==0:
        is_prime = False
print(is_prime)
# Out:
# True

# %%
text = "abc del gni jal mno pr"
for i in text:
    print(i,end="")
    if i==" ":
        print()
# Out:
# abc
# del
# gni
# jal
# mno
# pr

# %%
i = 0
while True:
    print("while loop", i)
    i = i+1
# Out:
# while loop 0
# while loop 1
# while loop 2
# while loop 3
# while loop 4
# while loop 5
# while loop 6
# while loop 7
# while loop 8
# while loop 9
# while loop 10
# while loop 11
# while loop 12
# while loop 13
# while loop 14
# while loop 15
# while loop 16
# while loop 17
# while loop 18
# while loop 19
# while loop 20
# while loop 21
# while loop 22
# while loop 23
# while loop 24
# while loop 25
# while loop 26
# while loop 27
# while loop 28
# while loop 29
# while loop 30
# while loop 31
# while loop 32
# while loop 33
# while loop 34
# while loop 35
# while loop 36
# while loop 37
# while loop 38
# while loop 39
# while loop 40
# while loop 41
# while loop 42
# while loop 43
# while loop 44
# while loop 45
# while loop 46
# while loop 47
# while loop 48
# while loop 49
# while loop 50
# while loop 51
# while loop 52
# while loop 53
# while loop 54
# while loop 55
# while loop 56
# while loop 57
# while loop 58
# while loop 59
# while loop 60
# while loop 61
# while loop 62
# ...

# %%
i = 10
while i:
    print("while loop",i)
    i = i-1
# Out:
# while loop 10
# while loop 9
# while loop 8
# while loop 7
# while loop 6
# while loop 5
# while loop 4
# while loop 3
# while loop 2
# while loop 1

# %%
i = 1
n = 5
while i<=10:
    print("while loop",i*n)
    i =i+1
# Out:
# while loop 5
# while loop 10
# while loop 15
# while loop 20
# while loop 25
# while loop 30
# while loop 35
# while loop 40
# while loop 45
# while loop 50

# %%
def sqrt(x):
    return x**(0.5)

# %%
sqrt(2)
# Out:
# 1.4142135623730951

# %%
sqrt(16)
# Out:
# 4.0

# %%
def calc(a,b):
    add = a+b
    sub = a-b
    div = a/b
    mul = a*b
    return add,sub,mul,div

# %%
calc(12,10)
# Out:
# (22, 2, 120, 1.2)

# %%
def great(name):
    return "welcome :"+name

# %%
great(name = "satender")
# Out:
# 'welcome :satender'

# %%
def add(a,b):
    add=a+b
    return add

# %%
add(5,6)
# Out:
# 11
