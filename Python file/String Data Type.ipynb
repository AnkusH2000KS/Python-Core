# %%
a = 12
b = 90

# %%
a,b = 56,90

# %%
a = b = c = 8

# %%
a = 1,2,34,55,6
a
# Out:
# (1, 2, 34, 55, 6)

# %%
a,b = 12,34,5,67
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/919540251.py in <module>
# ----> 1 a,b = 12,34,5,67
#
# ValueError: too many values to unpack (expected 2)

# %%
a,b,c,d,e = 12,34,5,67
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/2620779474.py in <module>
# ----> 1 a,b,c,d,e = 12,34,5,67
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
a,b,*c = 12,34,45,56,67,78,90

# %%
a,b,c
# Out:
# (12, 34, [45, 56, 67, 78, 90])

# %%
a,*b,c = 12,34,45,56,67,78,90

# %%
a,b,c
# Out:
# (12, [34, 45, 56, 67, 78], 90)

# %%
from PIL import Image

# %%
img = Image.open('dtype.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=794x1123 at 0x27C39DDE8E0>

# %%
int
# Out:
# int

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
# binary
0b10101
# Out:
# 21

# %%
# hex
0xa
# Out:
# 10

# %%
# oct
0o12
# Out:
# 10

# %%
# type casting 
# convert into integer (int)
int(23) # int to int
int(23.45) # float to int
int('23') # str (numeric integer string) to int
int('23.9') #  Value Error

# %%
chr(65)
# Out:
# 'A'

# %%
ord("A")
# Out:
# 65

# %%
################### float

# %%
f = 23.89
type(f)
# Out:
# float

# %%
1e3
# Out:
# 1000.0

# %%
0.000000000000000011111111111
# Out:
# 1.1111111111e-17

# %%
float(23) # int to float
float(23.34) # float to float
float('23') # str to float
float('23.0') # str to float

# %%
################### bool

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True*10
# Out:
# 10

# %%
False*10
# Out:
# 0

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(-10)
# Out:
# True

# %%
bool(253625)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
# string Concatenation 

s1 = 'first '
s2 = "sEcond"
s = s1 + s2
s
# Out:
# 'first sEcond'

# %%
# only concatenate str to str , not str to int
a = 20
'total ='+a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/3801256390.py in <module>
#       1 # only concatenate str to str , not str to int
#       2 a = 20
# ----> 3 'total ='+a
#
# TypeError: can only concatenate str (not "int") to str

# %%
# convert number to string
a = 50.0
s = str(a)

type(s),s
# Out:
# (str, '50.0')

# %%
a = 20

s = 'total = '+ str(a)
s
# Out:
# 'total = 20'

# %%
s = 'For more general types, including those'

# %%
s = "For more general types, including those"

# %%
s = "For more 'general' types, including those"

# %%
s = """
In computer science and computer programming,
a data type or simply type is an attribute of data
which tells the compiler or interpreter how the 
programmer intends to use the data. Most programming 
languages support basic data types of integer numbers
(of varying sizes), floating-point numbers (which approximate real numbers), characters and Booleans. A data type constrains the values that an expression, such as a variable or a function, might take. This data type defines the operations that can be done on the data, the meaning of the data, and the way values of that type can be stored. 
A data type provides a set of values from which an expression (i.e. variable, function, etc.) may take its values
"""

# %%
print(s)
# Out:
# In computer science and computer programming,
# a data type or simply type is an attribute of data
# which tells the compiler or interpreter how the
# programmer intends to use the data. Most programming
# languages support basic data types of integer numbers
# (of varying sizes), floating-point numbers (which approximate real numbers), characters and Booleans. A data type constrains the values that an expression, such as a variable or a function, might take. This data type defines the operations that can be done on the data, the meaning of the data, and the way values of that type can be stored.
# A data type provides a set of values from which an expression (i.e. variable, function, etc.) may take its values

# %%
s = 'fhfhhghgjhf df sd f s gf \
sd gs dg df gdf g'

# %%
print(s)
# Out:
# fhfhhghgjhf df sd f s gf sd gs dg df gdf g

# %%
12 + 34 + 
78
# Out:
#   File "C:\Users\Hp\AppData\Local\Temp/ipykernel_8764/1036208756.py", line 1
#     12 + 34 +
#               ^
# SyntaxError: invalid syntax

# %%
12 + 34 + \
78
# Out:
# 124

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.hexdigits
# Out:
# '0123456789abcdefABCDEF'

# %%
s = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
len(s)
# Out:
# 26

# %%
# var_name[]

# %%
s[0]
# Out:
# 'A'

# %%
s[25]
# Out:
# 'Z'

# %%
s[-1]
# Out:
# 'Z'

# %%
s[-26]
# Out:
# 'A'

# %%
s[26]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/1456488325.py in <module>
# ----> 1 s[26]
#
# IndexError: string index out of range

# %%
s[-27]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8764/196077078.py in <module>
# ----> 1 s[-27]
#
# IndexError: string index out of range

# %%
# var_name[start_index:end_index]

# %%
s[0:5]
# Out:
# 'ABCDE'

# %%
s[3:5]
# Out:
# 'DE'

# %%
s[4:5]
# Out:
# 'E'

# %%
s[5:5]
# Out:
# ''

# %%
# var_name[start_index:end_index:step_value]

# %%
s[0:20:1]
# Out:
# 'ABCDEFGHIJKLMNOPQRST'

# %%
s[0:20:2]
# Out:
# 'ACEGIKMOQS'

# %%
s[0:20:5]
# Out:
# 'AFKP'

# %%
# default

# %%
s[:20]
# Out:
# 'ABCDEFGHIJKLMNOPQRST'

# %%
s[20:]
# Out:
# 'UVWXYZ'

# %%
s[:]
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
s[::]
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
s[::2]
# Out:
# 'ACEGIKMOQSUWY'

# %%
########################

# %%
s[25:20]
# Out:
# ''

# %%
s[25:20:-1]
# Out:
# 'ZYXWV'

# %%
s[:20:-1]
# Out:
# 'ZYXWV'

# %%
s[:-26:-1]
# Out:
# 'ZYXWVUTSRQPONMLKJIHGFEDCB'

# %%
s[::-1]
# Out:
# 'ZYXWVUTSRQPONMLKJIHGFEDCBA'

# %%
#################################################

# %%
s[-26:10]
# Out:
# 'ABCDEFGHIJ'

# %%
s1 = s[:14]
s2 = s[14:]
s1,s2
# Out:
# ('ABCDEFGHIJKLMN', 'OPQRSTUVWXYZ')

# %%
 ###########################

# %%
# string formating

# %%
name = input("Enter Your Name ? ") 
age = input("Enter Your Age ? ") 
ph = input("Enter Your Phone Number  ? ") 
text = """

name : {}
age : {}
ph : {}
"""
# Out:
# Enter Your Name ? 11
# Enter Your Age ? 32
# Enter Your Phone Number  ? 23

# %%
print(text)
# Out:
# name : {}
# age : {}
# ph : {}

# %%
name = input("Enter Your Name ? ") 
age = input("Enter Your Age ? ") 
ph = input("Enter Your Phone Number  ? ") 
text = """

name : {name}
age : {age}
ph : {ph}
"""
# Out:
# Enter Your Name ? abhi
# Enter Your Age ? 32
# Enter Your Phone Number  ? 82738273

# %%
print(text)
# Out:
# name : {name}
# age : {age}
# ph : {ph}

# %%
name = input("Enter Your Name ? ") 
age = input("Enter Your Age ? ") 
ph = input("Enter Your Phone Number  ? ") 
text = f"""
name : {name}
age : {age}
ph : {ph}
"""
print(text)
# Out:
# Enter Your Name ? Md
# Enter Your Age ? 32
# Enter Your Phone Number  ? 34534534
#
# name : Md
# age : 32
# ph : 34534534

# %%
import time
name = input("Enter Your Name ? ") 
age = input("Enter Your Age ? ") 
ph = input("Enter Your Phone Number  ? ") 
text = f"""
name : {name}
age : {age}
ph : {ph}
date time : {time.ctime()}
"""
print(text)
# Out:
# Enter Your Name ? abc
# Enter Your Age ? 56
# Enter Your Phone Number  ? 25362536253
#
# name : abc
# age : 56
# ph : 25362536253
# date time : Thu Feb 17 13:26:05 2022

# %%
a = 90
b = 76

f'{a} + {b} = {a+b}'
# Out:
# '90 + 76 = 166'

# %%
f = open('mydata.txt','w')
f.write(text)
f.close()

# %%
##########################

# %%
b = input("Name  ")
# Out:
# Name  Ankush

# %%
b
# Out:
# 'Ankush'

# %%
str1 = "James"
output:'Jms'

# %%
str1[0]+str1[2]+str1[-1]
# Out:
# 'Jms'

# %%
str1[::2]
# Out:
# 'Jms'

# %%
s = 'studenttraining111gmail.com'

# %%
s[:18]  + '@' + s[18:]
# Out:
# 'studenttraining111@gmail.com'

# %%
a = 'shaminasingh'

# %%
a[:7] + ' ' + a[7:]
# Out:
# 'shamina singh'

# %%
b='AbhishekTiwari'

# %%
b[:8] + '    ' + b [8:]
# Out:
# 'Abhishek    Tiwari'

# %%
z  = 'Bankukumar'

# %%
z[:5]  + ' OP ' + z[5:]
# Out:
# 'Banku OP kumar'
